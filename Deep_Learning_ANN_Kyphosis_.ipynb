# %% [markdown]
# <a href="https://colab.research.google.com/github/amankv38/Deep-Learning/blob/main/Deep_Learning_ANN_Kyphosis_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('/content/drive/MyDrive/ML deployment datasets/nasopharyngeal prediction.csv')

# %%
data
# Out:
#      Age  Gender  Air Pollution  Alcohol use  Smoking  Passive Smoker  \
# 0     33       1              2            4        3               2
# 1     17       1              3            1        2               4
# 2     35       1              4            5        2               3
# 3     37       1              7            7        7               7
# 4     46       1              6            8        8               7
# ..   ...     ...            ...          ...      ...             ...
# 995   44       1              6            7        7               8
# 996   37       2              6            8        7               8
# 997   25       2              4            5        2               3
# 998   18       2              6            8        8               7
# 999   47       1              6            5        2               3
#
#      Frequent Cold  Dry Cough  Snoring   Level
# 0                2          3        4     Low
# ...

# %%
data.isna().sum()
# Out:
# Age               0
# Gender            0
# Air Pollution     0
# Alcohol use       0
# Smoking           0
# Passive Smoker    0
# Frequent Cold     0
# Dry Cough         0
# Snoring           0
# Level             0
# dtype: int64

# %%
from sklearn import preprocessing
lr=preprocessing.LabelEncoder()

# %%
data['Level']=lr.fit_transform(data['Level'])

# %%
data
# Out:
#      Age  Gender  Air Pollution  Alcohol use  Smoking  Passive Smoker  \
# 0     33       1              2            4        3               2
# 1     17       1              3            1        2               4
# 2     35       1              4            5        2               3
# 3     37       1              7            7        7               7
# 4     46       1              6            8        8               7
# ..   ...     ...            ...          ...      ...             ...
# 995   44       1              6            7        7               8
# 996   37       2              6            8        7               8
# 997   25       2              4            5        2               3
# 998   18       2              6            8        8               7
# 999   47       1              6            5        2               3
#
#      Frequent Cold  Dry Cough  Snoring  Level
# 0                2          3        4      1
# ...

# %%
x=data.drop('Level', axis=1)

# %%
y=data.Level

# %%
x
# Out:
#      Age  Gender  Air Pollution  Alcohol use  Smoking  Passive Smoker  \
# 0     33       1              2            4        3               2
# 1     17       1              3            1        2               4
# 2     35       1              4            5        2               3
# 3     37       1              7            7        7               7
# 4     46       1              6            8        8               7
# ..   ...     ...            ...          ...      ...             ...
# 995   44       1              6            7        7               8
# 996   37       2              6            8        7               8
# 997   25       2              4            5        2               3
# 998   18       2              6            8        8               7
# 999   47       1              6            5        2               3
#
#      Frequent Cold  Dry Cough  Snoring
# 0                2          3        4
# 1                1          7        2
# ...

# %%
y
# Out:
# 0      1
# 1      2
# 2      0
# 3      0
# 4      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: Level, Length: 1000, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train
# Out:
#      Age  Gender  Air Pollution  Alcohol use  Smoking  Passive Smoker  \
# 727   61       1              2            3        3               2
# 245   29       2              6            7        7               7
# 559   37       1              7            7        7               7
# 603   24       2              1            2        2               1
# 814   28       1              6            7        4               3
# ..   ...     ...            ...          ...      ...             ...
# 746   52       2              1            2        3               2
# 833   52       1              3            2        7               2
# 932   22       2              2            1        6               1
# 770   26       2              7            7        7               7
# 289   33       1              1            6        3               4
#
#      Frequent Cold  Dry Cough  Snoring
# 727              2          1        2
# 245              2          3        1
# ...

# %%
y_train
# Out:
# 727    1
# 245    0
# 559    0
# 603    1
# 814    1
#       ..
# 746    2
# 833    1
# 932    1
# 770    0
# 289    2
# Name: Level, Length: 700, dtype: int64

# %%
x_test
# Out:
#      Age  Gender  Air Pollution  Alcohol use  Smoking  Passive Smoker  \
# 568   38       2              2            1        1               4
# 38    32       1              2            3        4               3
# 470   38       1              2            1        1               4
# 344   64       1              6            8        7               8
# 487   17       2              1            2        3               2
# ..   ...     ...            ...          ...      ...             ...
# 281   38       1              2            3        4               3
# 148   28       1              6            7        4               3
# 997   25       2              4            5        2               3
# 684   36       1              6            7        7               7
# 492   24       2              1            2        2               1
#
#      Frequent Cold  Dry Cough  Snoring
# 568              3          2        3
# 38               2          5        1
# ...

# %%
y_test
# Out:
# 568    2
# 38     1
# 470    2
# 344    0
# 487    1
#       ..
# 281    1
# 148    1
# 997    0
# 684    0
# 492    1
# Name: Level, Length: 300, dtype: int64

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

model=tf.keras.Sequential([tf.keras.layers.Dense(1)])
model.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])
model.fit(x_test, y_test, epochs=5)
# Out:
# Epoch 1/5
# 10/10 [==============================] - 1s 3ms/step - loss: 14.0367 - accuracy: 0.3967
# Epoch 2/5
# 10/10 [==============================] - 0s 2ms/step - loss: 14.0367 - accuracy: 0.3967
# Epoch 3/5
# 10/10 [==============================] - 0s 2ms/step - loss: 14.0367 - accuracy: 0.3967
# Epoch 4/5
# 10/10 [==============================] - 0s 3ms/step - loss: 14.0367 - accuracy: 0.3967
# Epoch 5/5
# 10/10 [==============================] - 0s 3ms/step - loss: 14.0367 - accuracy: 0.3967
